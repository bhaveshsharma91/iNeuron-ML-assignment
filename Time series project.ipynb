# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from pandas.tools.plotting import autocorrelation_plot 
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA, ARMAResults
import datetime
import sys
import seaborn as sns
import statsmodels
import statsmodels.stats.diagnostic as diag
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# %%
from scipy.stats.mstats import normaltest
from matplotlib.pyplot import acorr


plt.style.use('fivethirtyeight')
# %matplotlib inline


df = pd.read_csv('data_stocks.csv')
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
# ...

# %%
for i in df.isna().sum():
    if i != 0:
        print(i)
        
# no output prints meaning no missing values

# %% [raw]
#  we only need to pick up the columns:
# 1. NASDAQ.AAPL
# 2. NASDAQ.ADP
# 3. NASDAQ.CBOE
# 4. NASDAQ.CSCO
# 5. NASDAQ.EBAY

# %%
df1 = df.copy()
df1['DATE'] = pd.to_datetime(df["DATE"],unit='s')
cols = df1['DATE'].values
df1 = pd.DataFrame(data=df1)
df1.set_index('DATE', inplace=True)
df1.head()
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-04-03 13:30:00      82.040    102.2300      85.2200       59.760
# 2017-04-03 13:31:00      82.080    102.1400      85.6500       59.840
# 2017-04-03 13:32:00      82.030    102.2125      85.5100       59.795
# 2017-04-03 13:33:00      82.000    102.1400      85.4872       59.620
# 2017-04-03 13:34:00      82.035    102.0600      85.7001       59.620
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.WYN  NYSE.XEC  \
# ...

# %%
df = df1[[ "NASDAQ.AAPL"
, "NASDAQ.ADP"
, "NASDAQ.CBOE"
, "NASDAQ.CSCO"
,"NASDAQ.EBAY"]]

# %%
df
# Out:
#                      NASDAQ.AAPL  NASDAQ.ADP  NASDAQ.CBOE  NASDAQ.CSCO  \
# DATE
# 2017-04-03 13:30:00     143.6800    102.2300        81.03      33.7400
# 2017-04-03 13:31:00     143.7000    102.1400        81.21      33.8800
# 2017-04-03 13:32:00     143.6901    102.2125        81.21      33.9000
# 2017-04-03 13:33:00     143.6400    102.1400        81.13      33.8499
# 2017-04-03 13:34:00     143.6600    102.0600        81.12      33.8400
# ...                          ...         ...          ...          ...
# 2017-08-31 19:56:00     164.1100    106.5650       100.89      32.1850
# 2017-08-31 19:57:00     164.1200    106.5900       100.88      32.2000
# 2017-08-31 19:58:00     164.0100    106.5200       100.86      32.2000
# 2017-08-31 19:59:00     163.8800    106.4000       100.83      32.1950
# 2017-08-31 20:00:00     163.9800    106.4700       100.89      32.2250
#
#                      NASDAQ.EBAY
# DATE
# 2017-04-03 13:30:00      33.3975
# 2017-04-03 13:31:00      33.3950
# ...

# %%
df.plot()
# Out:
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# ...

# %%
moving_average_df=df.rolling(window=5).mean()  # window: This is the number of observations used for calculating the statistic. 
moving_average_df.plot();
# Out:
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# ...

# %%
sm.stats.durbin_watson(df) # very less correlation
# Out:
# array([3.85921421e-07, 5.15045512e-07, 2.71132274e-07, 4.41426683e-07,
#        4.45419397e-07])

# %%
# %matplotlib inline
for i in df.columns:
    fig = plt.figure(figsize=(12,8))
    ax1 = fig.add_subplot(211)
    fig = sm.graphics.tsa.plot_acf(df[i].values.squeeze(), lags=40, ax=ax1)
    ax2 = fig.add_subplot(212)
    fig = sm.graphics.tsa.plot_pacf(df[i], lags=44, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df["NASDAQ.EBAY"].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df["NASDAQ.EBAY"], lags=44, ax=ax2)

# %%
mse = []
aic = []
for i in df.columns:
    training_data=df[i][0:35000]
    test_data=df[i][35000:]
    arima= ARIMA(training_data, order=(1,0,0));
    model=arima.fit()
    pred= model.forecast(steps=6266)[0]
    aic.append([str(i), str(model.aic)])
    mse.append([str(i), str(np.sqrt(mean_squared_error(test_data,pred)))]);
# Out:
# c:\users\syed rahim saqib\python_miniconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# ### answer

# %%
aic
# Out:
# [['NASDAQ.AAPL', '-66240.35563074648'],
#  ['NASDAQ.ADP', '-80883.57741916743'],
#  ['NASDAQ.CBOE', '-115294.58679761046'],
#  ['NASDAQ.CSCO', '-169323.9249140736'],
#  ['NASDAQ.EBAY', '-162313.604247718']]

# %%
mse
# Out:
# [['NASDAQ.AAPL', '4.034606003838448'],
#  ['NASDAQ.ADP', '2.4426269155814415'],
#  ['NASDAQ.CBOE', '2.657523052577874'],
#  ['NASDAQ.CSCO', '0.7166489855024666'],
#  ['NASDAQ.EBAY', '0.6760409416988439']]
